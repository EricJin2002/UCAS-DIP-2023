# %% [markdown]
# # 图像拼接

# %%
from img_stitching import *

# %%
for id in [1,2,3,4]:
    left_path = "images/left"+str(id)+".jpg"
    right_path = "images/right"+str(id)+".jpg"
    left = read_to_rgb(left_path, plot=True)
    right = read_to_rgb(right_path, plot=True)
    _ = stitch_img(left, right, save_suffix=str(id))
# Out:
# load data from cache:  cache/left_kp1.pkl
# load data from cache:  cache/right_kp1.pkl
# left keypoint number:  13430
# left descriptor shape:  (13430, 128)
# right keypoint number:  5652
# right descriptor shape:  (5652, 128)
# load data from cache:  cache/matches1.pkl
# matches number:  13430
# good matches number:  245
# left good keypoint number:  245
# right good keypoint number:  245
# left good keypoint shape:  (245, 1, 2)
# right good keypoint shape:  (245, 1, 2)
# M:  [[ 6.56251800e-01 -3.82905145e-02  2.64400781e+03]
#  [-3.37069823e-03  7.02073910e-01  3.18132308e+02]
#  [-1.38276627e-05  2.43168050e-06  1.00000000e+00]]
# mask shape:  (245, 1)
# left_corners:  [[[2644.0078  318.1323]]
#
#  [[2379.5903 4464.7437]]
#
#  [[5252.478  4708.055 ]]
#
#  [[5576.7344  322.4853]]]
# h_max:  4708.055
# w_max:  5576.7344
# left shape:  (6000, 4000, 3)
# right shape:  (6000, 4000, 3)
# h_bigger:  6000
# w_bigger:  5576.7344
# mask shape:  (6000, 5576)
# left_bound:  2379
# ...

# %% [markdown]
# ## 参考资料
# - [python实现基于SIFT算法的图像配准（仿射变换）](https://blog.csdn.net/lyxleft/article/details/89476175)
# - [OpenCV - SIFT 参数及计算返回结果说明](https://www.aiuai.cn/aifarm1639.html)
# - [OpenCV探索之路（二十四）图像拼接和图像融合技术](https://www.cnblogs.com/skyfsm/p/7411961.html)
